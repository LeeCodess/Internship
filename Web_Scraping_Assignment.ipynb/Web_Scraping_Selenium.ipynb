# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\yadav\anaconda3\lib\site-packages (4.4.3)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\yadav\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\yadav\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio~=0.17 in c:\users\yadav\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\yadav\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: sniffio in c:\users\yadav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\yadav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\yadav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: idna in c:\users\yadav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: async-generator>=1.9 in c:\users\yadav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\yadav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\yadav\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\yadav\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\yadav\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\yadav\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\yadav\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %% [markdown]
# # (Q1)

# %% [markdown]
# Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
#
# This task will be done in following steps -
#
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field
# 3. Then click the search button
# 4. Then scrape the data for the first 10 jobs results you get
# 5. Finally create a dataframe of the scraped data

# %%
# importing all the necessary libraries
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import warnings
warnings.filterwarnings("ignore")

# %%
# connecting with the driver
driver = webdriver.Chrome("chromedriver.exe")

# pulling the website
driver.get('https://www.naukri.com')

# %%
# entering the designation
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
# entering the location
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title = []
job_location =[]
company_name = []
experience_required =[]

# %%
# scraping the title
title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
job_title
# Out:
# ['Senior Data Analyst',
#  'Data Analyst',
#  'Hiring For Data Analyst (DA)/ Team Lead (TL) -Clinical Data management',
#  'Call For Clinical Data Analyst - Hyd/Bangalore/Pune/Mumbai/Kolkata',
#  'Payroll Transformation Data Analyst',
#  'Payroll Transformation Data Analyst',
#  'Master Data Management Business Analyst',
#  'Data Analytics and Interpretation Business Analyst',
#  'HR Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Hiring For Data Analyst (DA)/ Team Lead (TL) -Clinical Data management',
#  'Call For Clinical Data Analyst - Hyd/Bangalore/Pune/Mumbai/Kolkata',
#  'Payroll Transformation Data Analyst',
#  'Payroll Transformation Data Analyst',
#  'Master Data Management Business Analyst',
#  'Data Analytics and Interpretation Business Analyst',
#  'HR Data Analyst',
#  'Data Analyst']

# %%
# scraping the location
location_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
job_location
# Out:
# ['Bangalore/Bengaluru, Chennai',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Kolkata, Hyderabad/Secunderabad, Pune, Mumbai (All Areas)',
#  'Bangalore/Bengaluru, Kolkata, Hyderabad/Secunderabad, Pune, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Chennai',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Kolkata, Hyderabad/Secunderabad, Pune, Mumbai (All Areas)',
#  'Bangalore/Bengaluru, Kolkata, Hyderabad/Secunderabad, Pune, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
# scraping the company name
company_tags= driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
company_name
# Out:
# ['Latentview',
#  'Jar',
#  'Cognizant',
#  'Cognizant',
#  'Arrow Electronics',
#  'Arrow Electronics',
#  'Accenture',
#  'Accenture',
#  'Hitachi Ltd.',
#  'ANZ',
#  'Latentview',
#  'Jar',
#  'Cognizant',
#  'Cognizant',
#  'Arrow Electronics',
#  'Arrow Electronics',
#  'Accenture',
#  'Accenture',
#  'Hitachi Ltd.',
#  'ANZ']

# %%
# scraping experience
experience_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)
experience_required
# Out:
# ['3-6 Yrs',
#  '0-4 Yrs',
#  '3-8 Yrs',
#  '6-9 Yrs',
#  '3-7 Yrs',
#  '5-10 Yrs',
#  '6-8 Yrs',
#  '6-8 Yrs',
#  '3-6 Yrs',
#  '7-12 Yrs',
#  '3-6 Yrs',
#  '0-4 Yrs',
#  '3-8 Yrs',
#  '6-9 Yrs',
#  '3-7 Yrs',
#  '5-10 Yrs',
#  '6-8 Yrs',
#  '6-8 Yrs',
#  '3-6 Yrs',
#  '7-12 Yrs']

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
df = pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'experience_required':experience_required})
df
# Out:
#                                             job_title  \
# 0                                 Senior Data Analyst
# 1                                        Data Analyst
# 2   Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 3   Call For Clinical Data Analyst - Hyd/Bangalore...
# 4                 Payroll Transformation Data Analyst
# 5                 Payroll Transformation Data Analyst
# 6             Master Data Management Business Analyst
# 7   Data Analytics and Interpretation Business Ana...
# 8                                     HR Data Analyst
# 9                                        Data Analyst
# 10                                Senior Data Analyst
# 11                                       Data Analyst
# 12  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 13  Call For Clinical Data Analyst - Hyd/Bangalore...
# 14                Payroll Transformation Data Analyst
# 15                Payroll Transformation Data Analyst
# 16            Master Data Management Business Analyst
# 17  Data Analytics and Interpretation Business Ana...
# 18                                    HR Data Analyst
# 19                                       Data Analyst
#
#                                          job_location       company_name  \
# 0                        Bangalore/Bengaluru, Chennai         Latentview
# 1                                 Bangalore/Bengaluru                Jar
# 2   Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...          Cognizant
# 3   Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...          Cognizant
# 4                                 Bangalore/Bengaluru  Arrow Electronics
# 5                                 Bangalore/Bengaluru  Arrow Electronics
# 6                                 Bangalore/Bengaluru          Accenture
# 7                                 Bangalore/Bengaluru          Accenture
# 8                                 Bangalore/Bengaluru       Hitachi Ltd.
# 9                                 Bangalore/Bengaluru                ANZ
# 10                       Bangalore/Bengaluru, Chennai         Latentview
# 11                                Bangalore/Bengaluru                Jar
# 12  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...          Cognizant
# 13  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...          Cognizant
# 14                                Bangalore/Bengaluru  Arrow Electronics
# 15                                Bangalore/Bengaluru  Arrow Electronics
# 16                                Bangalore/Bengaluru          Accenture
# 17                                Bangalore/Bengaluru          Accenture
# 18                                Bangalore/Bengaluru       Hitachi Ltd.
# 19                                Bangalore/Bengaluru                ANZ
#
#    experience_required
# 0              3-6 Yrs
# 1              0-4 Yrs
# 2              3-8 Yrs
# 3              6-9 Yrs
# 4              3-7 Yrs
# 5             5-10 Yrs
# 6              6-8 Yrs
# 7              6-8 Yrs
# 8              3-6 Yrs
# 9             7-12 Yrs
# 10             3-6 Yrs
# 11             0-4 Yrs
# 12             3-8 Yrs
# 13             6-9 Yrs
# 14             3-7 Yrs
# 15            5-10 Yrs
# 16             6-8 Yrs
# 17             6-8 Yrs
# 18             3-6 Yrs
# 19            7-12 Yrs

# %% [markdown]
# # (Q2)

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
#
# This task will be done in following steps -
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field
# 3. Then click the search button
# 4. Then scrape the data for the first 10 jobs results you get
# 5. Finally create a dataframe of the scraped data

# %%
# pulling the website
driver.get("https://www.naukri.com/")

# %%
# entering the designation
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
# entering the location
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[6]")
search.click()

# %%
job_title = []
job_location =[]
company_name = []

# %%
# scraping the title
title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
job_title
# Out:
# ['Data Science Specialist',
#  'Data Science Manager',
#  'Mongodb Database Administrator, Maria DB or Cassandra',
#  'Analystics & Modeling Specialist',
#  'Assistant Manager - Data Science',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Industry X - Software Engineering',
#  'Module Lead - BIDW',
#  'Data Scientist: Artificial Intelligence']

# %%
# scraping the location
location_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
job_location
# Out:
# ['Bangalore/Bengaluru, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai',
#  'Bangalore/Bengaluru, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai',
#  'Bangalore/Bengaluru, Hyderabad/Secunderabad, Pune, Chennai, Delhi / NCR, Mumbai (All Areas)',
#  'Bangalore/Bengaluru, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, delhi ncr',
#  'Bangalore/Bengaluru, Mumbai, Pune',
#  'Bangalore/Bengaluru, Hyderabad/Secunderabad, Pune, Chennai',
#  'Bangalore/Bengaluru, Mumbai, New Delhi, Chennai',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
# scraping the company name
company_tags= driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
company_name
# Out:
# ['Accenture',
#  'Accenture',
#  'Mphasis',
#  'Accenture',
#  'CitiusTech',
#  'Tech Mahindra',
#  'Boston Consulting Group',
#  'Accenture',
#  'Mphasis',
#  'IBM']

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
df = pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name})
df
# Out:
#                                            job_title  \
# 0                            Data Science Specialist
# 1                               Data Science Manager
# 2  Mongodb Database Administrator, Maria DB or Ca...
# 3                   Analystics & Modeling Specialist
# 4                   Assistant Manager - Data Science
# 5                                     Data Scientist
# 6                              Senior Data Scientist
# 7                  Industry X - Software Engineering
# 8                                 Module Lead - BIDW
# 9            Data Scientist: Artificial Intelligence
#
#                                         job_location             company_name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 2  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...                  Mphasis
# 3  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 4                  Bangalore/Bengaluru, Mumbai, Pune               CitiusTech
# 5  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...            Tech Mahindra
# 6    Bangalore/Bengaluru, Mumbai, New Delhi, Chennai  Boston Consulting Group
# 7                                Bangalore/Bengaluru                Accenture
# 8                                Bangalore/Bengaluru                  Mphasis
# 9                                Bangalore/Bengaluru                      IBM

# %% [markdown]
# # (Q3)

# %% [markdown]
# In this question you have to scrape data using the filters available on the webpage as shown below -
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
#
# The task will be done as shown in the below steps -
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field
# 3. Then click the search button
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get
# 6. Finally create a dataframe of the scraped data

# %%
driver=webdriver.Chrome("chromedriver.exe")

# pulling the website
driver.get("https://www.naukri.com/")

# %%
# entering the designation
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
# entering the location
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Delhi/NCR')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[6]")
search.click()

# %%
# location is delhi/ncr
job_location = driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[13]/div[2]/div[2]/label/p/span[1]")
job_location.click()

# %%
# salary is 3-6 lakhs 
salary = driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]")
salary.click()

# %%
job_title = []
job_location =[]
company_name = []
experience_required =[]

# %%
# scraping the title
title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
job_title
# Out:
# ['Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data scientist- Python']

# %%
# scraping the Location 
location_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
job_location
# Out:
# ['Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram, Dehradun, Hyderabad/Secunderabad',
#  'Gurgaon/Gurugram']

# %%
# scraping the company name 
company_tags= driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
company_name
# Out:
# ['IHS Markit',
#  'Optum',
#  'torcai digital media',
#  'TeamPlus Staffing Solution Pvt Ltd']

# %%
# scraping the experience
experience_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)
experience_required
# Out:
# ['3-6 Yrs', '2-7 Yrs', '2-7 Yrs', '3-6 Yrs']

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 4 4 4 4

# %%
df = pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'experience_required':experience_required})
df
# Out:
#                 job_title                                       job_location  \
# 0          Data Scientist                                   Gurgaon/Gurugram
# 1          Data Scientist                                   Gurgaon/Gurugram
# 2          Data Scientist  Gurgaon/Gurugram, Dehradun, Hyderabad/Secunder...
# 3  Data scientist- Python                                   Gurgaon/Gurugram
#
#                          company_name experience_required
# 0                          IHS Markit             3-6 Yrs
# 1                               Optum             2-7 Yrs
# 2                torcai digital media             2-7 Yrs
# 3  TeamPlus Staffing Solution Pvt Ltd             3-6 Yrs

# %% [markdown]
# # (Q4)

# %% [markdown]
# Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes -
#
# 1. Brand
# 2. Product Description
# 3. Price
#
# To scrape the data you have to go through following steps -
#
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data as usual
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100 sunglasses

# %%
driver=webdriver.Chrome("chromedriver.exe")

# pulling the website
driver.get("https://www.flipkart.com/")

# %%
popup= driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")

popup.click()

# %%
des= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

des.send_keys("Sunglasses")

# %%
search= driver.find_element(By.CLASS_NAME, "_34RNph")
search.click()

# %%
brand_name=[]
product_description=[]
price=[]
discount=[]

# %%
# brand
start=1
end=4
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') 
    next_button.click()
    time.sleep(8)
Top100_brand_name= brand_name[0:100]

# %%
# to the first page
prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# product
start=1
end=4
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100]

# %%
# to the first page
prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# price
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        x= i.text
        price.append(x)

    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100]

# %%
# to the first page
prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# discount
start=1
end=4
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in price_tags:
        x= i.text
        discount.append(x)
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') 
    next_button.click()
    time.sleep(5)
Top100_discount = discount[0:100] #Top 100 data

# %%
# to the first page
prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
print (len(Top100_brand_name), len(Top100_product_description), len(Top100_price), len(Top100_discount))
# Out:
# 100 100 100 100

# %%
data_list= list(zip(Top100_brand_name, Top100_product_description, Top100_price, Top100_discount))

df= pd.DataFrame(data_list, 
    columns =['brand_name', 'product_description', 'price', 'discount'],
    index=pd.RangeIndex(start=1, stop=101, name='serial. number.'))

df = df.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("first 100 sunglasses on flipkart.com - \n")
df
# Out:
# first 100 sunglasses on flipkart.com -
# <style type="text/css">
# #T_c3cfd_row0_col0, #T_c3cfd_row0_col1, #T_c3cfd_row0_col2, #T_c3cfd_row0_col3, #T_c3cfd_row1_col0, #T_c3cfd_row1_col1, #T_c3cfd_row1_col2, #T_c3cfd_row1_col3, #T_c3cfd_row2_col0, #T_c3cfd_row2_col1, #T_c3cfd_row2_col2, #T_c3cfd_row2_col3, #T_c3cfd_row3_col0, #T_c3cfd_row3_col1, #T_c3cfd_row3_col2, #T_c3cfd_row3_col3, #T_c3cfd_row4_col0, #T_c3cfd_row4_col1, #T_c3cfd_row4_col2, #T_c3cfd_row4_col3, #T_c3cfd_row5_col0, #T_c3cfd_row5_col1, #T_c3cfd_row5_col2, #T_c3cfd_row5_col3, #T_c3cfd_row6_col0, #T_c3cfd_row6_col1, #T_c3cfd_row6_col2, #T_c3cfd_row6_col3, #T_c3cfd_row7_col0, #T_c3cfd_row7_col1, #T_c3cfd_row7_col2, #T_c3cfd_row7_col3, #T_c3cfd_row8_col0, #T_c3cfd_row8_col1, #T_c3cfd_row8_col2, #T_c3cfd_row8_col3, #T_c3cfd_row9_col0, #T_c3cfd_row9_col1, #T_c3cfd_row9_col2, #T_c3cfd_row9_col3, #T_c3cfd_row10_col0, #T_c3cfd_row10_col1, #T_c3cfd_row10_col2, #T_c3cfd_row10_col3, #T_c3cfd_row11_col0, #T_c3cfd_row11_col1, #T_c3cfd_row11_col2, #T_c3cfd_row11_col3, #T_c3cfd_row12_col0, #T_c3cfd_row12_col1, #T_c3cfd_row12_col2, #T_c3cfd_row12_col3, #T_c3cfd_row13_col0, #T_c3cfd_row13_col1, #T_c3cfd_row13_col2, #T_c3cfd_row13_col3, #T_c3cfd_row14_col0, #T_c3cfd_row14_col1, #T_c3cfd_row14_col2, #T_c3cfd_row14_col3, #T_c3cfd_row15_col0, #T_c3cfd_row15_col1, #T_c3cfd_row15_col2, #T_c3cfd_row15_col3, #T_c3cfd_row16_col0, #T_c3cfd_row16_col1, #T_c3cfd_row16_col2, #T_c3cfd_row16_col3, #T_c3cfd_row17_col0, #T_c3cfd_row17_col1, #T_c3cfd_row17_col2, #T_c3cfd_row17_col3, #T_c3cfd_row18_col0, #T_c3cfd_row18_col1, #T_c3cfd_row18_col2, #T_c3cfd_row18_col3, #T_c3cfd_row19_col0, #T_c3cfd_row19_col1, #T_c3cfd_row19_col2, #T_c3cfd_row19_col3, #T_c3cfd_row20_col0, #T_c3cfd_row20_col1, #T_c3cfd_row20_col2, #T_c3cfd_row20_col3, #T_c3cfd_row21_col0, #T_c3cfd_row21_col1, #T_c3cfd_row21_col2, #T_c3cfd_row21_col3, #T_c3cfd_row22_col0, #T_c3cfd_row22_col1, #T_c3cfd_row22_col2, #T_c3cfd_row22_col3, #T_c3cfd_row23_col0, #T_c3cfd_row23_col1, #T_c3cfd_row23_col2, #T_c3cfd_row23_col3, #T_c3cfd_row24_col0, #T_c3cfd_row24_col1, #T_c3cfd_row24_col2, #T_c3cfd_row24_col3, #T_c3cfd_row25_col0, #T_c3cfd_row25_col1, #T_c3cfd_row25_col2, #T_c3cfd_row25_col3, #T_c3cfd_row26_col0, #T_c3cfd_row26_col1, #T_c3cfd_row26_col2, #T_c3cfd_row26_col3, #T_c3cfd_row27_col0, #T_c3cfd_row27_col1, #T_c3cfd_row27_col2, #T_c3cfd_row27_col3, #T_c3cfd_row28_col0, #T_c3cfd_row28_col1, #T_c3cfd_row28_col2, #T_c3cfd_row28_col3, #T_c3cfd_row29_col0, #T_c3cfd_row29_col1, #T_c3cfd_row29_col2, #T_c3cfd_row29_col3, #T_c3cfd_row30_col0, #T_c3cfd_row30_col1, #T_c3cfd_row30_col2, #T_c3cfd_row30_col3, #T_c3cfd_row31_col0, #T_c3cfd_row31_col1, #T_c3cfd_row31_col2, #T_c3cfd_row31_col3, #T_c3cfd_row32_col0, #T_c3cfd_row32_col1, #T_c3cfd_row32_col2, #T_c3cfd_row32_col3, #T_c3cfd_row33_col0, #T_c3cfd_row33_col1, #T_c3cfd_row33_col2, #T_c3cfd_row33_col3, #T_c3cfd_row34_col0, #T_c3cfd_row34_col1, #T_c3cfd_row34_col2, #T_c3cfd_row34_col3, #T_c3cfd_row35_col0, #T_c3cfd_row35_col1, #T_c3cfd_row35_col2, #T_c3cfd_row35_col3, #T_c3cfd_row36_col0, #T_c3cfd_row36_col1, #T_c3cfd_row36_col2, #T_c3cfd_row36_col3, #T_c3cfd_row37_col0, #T_c3cfd_row37_col1, #T_c3cfd_row37_col2, #T_c3cfd_row37_col3, #T_c3cfd_row38_col0, #T_c3cfd_row38_col1, #T_c3cfd_row38_col2, #T_c3cfd_row38_col3, #T_c3cfd_row39_col0, #T_c3cfd_row39_col1, #T_c3cfd_row39_col2, #T_c3cfd_row39_col3, #T_c3cfd_row40_col0, #T_c3cfd_row40_col1, #T_c3cfd_row40_col2, #T_c3cfd_row40_col3, #T_c3cfd_row41_col0, #T_c3cfd_row41_col1, #T_c3cfd_row41_col2, #T_c3cfd_row41_col3, #T_c3cfd_row42_col0, #T_c3cfd_row42_col1, #T_c3cfd_row42_col2, #T_c3cfd_row42_col3, #T_c3cfd_row43_col0, #T_c3cfd_row43_col1, #T_c3cfd_row43_col2, #T_c3cfd_row43_col3, #T_c3cfd_row44_col0, #T_c3cfd_row44_col1, #T_c3cfd_row44_col2, #T_c3cfd_row44_col3, #T_c3cfd_row45_col0, #T_c3cfd_row45_col1, #T_c3cfd_row45_col2, #T_c3cfd_row45_col3, #T_c3cfd_row46_col0, #T_c3cfd_row46_col1, #T_c3cfd_row46_col2, #T_c3cfd_row46_col3, #T_c3cfd_row47_col0, #T_c3cfd_row47_col1, #T_c3cfd_row47_col2, #T_c3cfd_row47_col3, #T_c3cfd ...

# %% [markdown]
# # (Q6)

# %% [markdown]
# Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
#
# You have to scrape 4 attributes of each sneaker -
# 1. Brand
# 2. Product Description
# 3. Price

# %%
driver= webdriver.Chrome(r"chromedriver.exe")

# pulling the website
driver.get("https://www.flipkart.com/")

# %%
popup= driver.find_element(By.XPATH, "/html/body/div[2]/div/div/button")
popup.click()

# %%
des= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

des.send_keys("sneakers")

# %%
search= driver.find_element(By.CLASS_NAME, "L0Z3Pu")
search.click()

# %%
brand_name=[]
product_description=[]
price=[]
discount=[]

# %%
# brand
start=0
end=3
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)
Top100_brand_name= brand_name[0:100]

# %%
len(brand_name)
# Out:
# 120

# %%
prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# product description
start=0
end=3
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100]

# %%
prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# price
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        x= i.text
        price.append(x)
        
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100]

# %%
prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# discount 
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in price_tags:
        x= i.text
        discount.append(x) 
     
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') 
    next_button.click()
    time.sleep(3)
Top100_discount = discount[0:100]

# %%
prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
list_data= list(zip(Top100_brand_name, Top100_product_description, Top100_price, Top100_discount))

df= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=101, name='serial. number.'),
        columns =['brand_name','product_description', 'price', 'discount'])

data = df.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("first 100 sneakers on Flipkart is - \n")
df
# Out:
# first 100 sneakers on Flipkart is -
#                      brand_name             product_description  \
# serial. number.
# 1                          Nike            Men Air Max Sneakers
# 2                          Puma
# 3                Tommy Hilfiger              Men Solid Sneakers
# 4                          Nike  Men REACT MILER 3 Running Shoe
# 5                      Skechers        Men ENIGMA Running Shoes
# ...                         ...                             ...
# 96                     Columbia  PEAKFREAK OUTDRY Trekking Shoe
# 97                         Puma  Women Velocity Nitro 2 Running
# 98                     Skechers                Men Sports Shoes
# 99                 Calvin Klein                    Men Sneakers
# 100                Calvin Klein            Men Leather Sneakers
#
#                                       price discount
# serial. number.
# 1                                  Rs. 8295  83% off
# 2                Rs. 8449Rs. 12999(35% OFF)  59% off
# 3                 Rs. 6639Rs. 8299(20% OFF)  76% off
# 4                Rs. 7871Rs. 10495(25% OFF)  82% off
# 5                                  Rs. 9499  71% off
# ...                                     ...      ...
# 96                                 Rs. 9999  80% off
# 97               Rs. 7699Rs. 10999(30% OFF)  65% off
# 98                                 Rs. 8499  52% off
# 99                Rs. 7679Rs. 9599(20% OFF)  76% off
# 100               Rs. 6879Rs. 8599(20% OFF)  68% off
#
# [100 rows x 4 columns]

# %% [markdown]
# # (Q7)

# %% [markdown]
# Go to the link - https://www.myntra.com/shoes
#
# Set second Price filter and Color filter to “Black”
#
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe
# description, price of the shoe

# %%
driver= webdriver.Chrome(r"chromedriver.exe")

driver.get(" https://www.myntra.com/shoes")

# %%
price_filter = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label')
price_filter.click()

# %%
color_filter = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label')
color_filter.click()

# %%
brand_name=[]
product_description=[]
price=[]

# %%
# brand
start=0
end=3
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
        
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]')
    next_button.click()
    time.sleep(3)
Top100_brand_name= brand_name[0:100]

# %%
prev_button= driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]/a')
prev_button.click()

# %%
# product description 
start=0
end=3
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
        
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100]

# %%
prev_button= driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]/a')
prev_button.click()

# %%
# price 
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="product-price"]')
    for i in price_tags:
        x= i.text
        price.append(x)
    
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]') 
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100]

# %%
print(len(Top100_brand_name), len(Top100_product_description), len(Top100_price))
# Out:
# 100 100 100

# %%
list_data= list(zip(Top100_brand_name, Top100_product_description, Top100_price))

df= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=101, name='serial. number.'),
        columns =['brand_name','product_description', 'price'])

df = df.style.set_properties(**{'text-align': 'right'})

print ("first 100 sneakers on Flipkart is:\n")
df
# Out:
# first 100 sneakers on Flipkart is:
# <style type="text/css">
# #T_51f9a_row0_col0, #T_51f9a_row0_col1, #T_51f9a_row0_col2, #T_51f9a_row1_col0, #T_51f9a_row1_col1, #T_51f9a_row1_col2, #T_51f9a_row2_col0, #T_51f9a_row2_col1, #T_51f9a_row2_col2, #T_51f9a_row3_col0, #T_51f9a_row3_col1, #T_51f9a_row3_col2, #T_51f9a_row4_col0, #T_51f9a_row4_col1, #T_51f9a_row4_col2, #T_51f9a_row5_col0, #T_51f9a_row5_col1, #T_51f9a_row5_col2, #T_51f9a_row6_col0, #T_51f9a_row6_col1, #T_51f9a_row6_col2, #T_51f9a_row7_col0, #T_51f9a_row7_col1, #T_51f9a_row7_col2, #T_51f9a_row8_col0, #T_51f9a_row8_col1, #T_51f9a_row8_col2, #T_51f9a_row9_col0, #T_51f9a_row9_col1, #T_51f9a_row9_col2, #T_51f9a_row10_col0, #T_51f9a_row10_col1, #T_51f9a_row10_col2, #T_51f9a_row11_col0, #T_51f9a_row11_col1, #T_51f9a_row11_col2, #T_51f9a_row12_col0, #T_51f9a_row12_col1, #T_51f9a_row12_col2, #T_51f9a_row13_col0, #T_51f9a_row13_col1, #T_51f9a_row13_col2, #T_51f9a_row14_col0, #T_51f9a_row14_col1, #T_51f9a_row14_col2, #T_51f9a_row15_col0, #T_51f9a_row15_col1, #T_51f9a_row15_col2, #T_51f9a_row16_col0, #T_51f9a_row16_col1, #T_51f9a_row16_col2, #T_51f9a_row17_col0, #T_51f9a_row17_col1, #T_51f9a_row17_col2, #T_51f9a_row18_col0, #T_51f9a_row18_col1, #T_51f9a_row18_col2, #T_51f9a_row19_col0, #T_51f9a_row19_col1, #T_51f9a_row19_col2, #T_51f9a_row20_col0, #T_51f9a_row20_col1, #T_51f9a_row20_col2, #T_51f9a_row21_col0, #T_51f9a_row21_col1, #T_51f9a_row21_col2, #T_51f9a_row22_col0, #T_51f9a_row22_col1, #T_51f9a_row22_col2, #T_51f9a_row23_col0, #T_51f9a_row23_col1, #T_51f9a_row23_col2, #T_51f9a_row24_col0, #T_51f9a_row24_col1, #T_51f9a_row24_col2, #T_51f9a_row25_col0, #T_51f9a_row25_col1, #T_51f9a_row25_col2, #T_51f9a_row26_col0, #T_51f9a_row26_col1, #T_51f9a_row26_col2, #T_51f9a_row27_col0, #T_51f9a_row27_col1, #T_51f9a_row27_col2, #T_51f9a_row28_col0, #T_51f9a_row28_col1, #T_51f9a_row28_col2, #T_51f9a_row29_col0, #T_51f9a_row29_col1, #T_51f9a_row29_col2, #T_51f9a_row30_col0, #T_51f9a_row30_col1, #T_51f9a_row30_col2, #T_51f9a_row31_col0, #T_51f9a_row31_col1, #T_51f9a_row31_col2, #T_51f9a_row32_col0, #T_51f9a_row32_col1, #T_51f9a_row32_col2, #T_51f9a_row33_col0, #T_51f9a_row33_col1, #T_51f9a_row33_col2, #T_51f9a_row34_col0, #T_51f9a_row34_col1, #T_51f9a_row34_col2, #T_51f9a_row35_col0, #T_51f9a_row35_col1, #T_51f9a_row35_col2, #T_51f9a_row36_col0, #T_51f9a_row36_col1, #T_51f9a_row36_col2, #T_51f9a_row37_col0, #T_51f9a_row37_col1, #T_51f9a_row37_col2, #T_51f9a_row38_col0, #T_51f9a_row38_col1, #T_51f9a_row38_col2, #T_51f9a_row39_col0, #T_51f9a_row39_col1, #T_51f9a_row39_col2, #T_51f9a_row40_col0, #T_51f9a_row40_col1, #T_51f9a_row40_col2, #T_51f9a_row41_col0, #T_51f9a_row41_col1, #T_51f9a_row41_col2, #T_51f9a_row42_col0, #T_51f9a_row42_col1, #T_51f9a_row42_col2, #T_51f9a_row43_col0, #T_51f9a_row43_col1, #T_51f9a_row43_col2, #T_51f9a_row44_col0, #T_51f9a_row44_col1, #T_51f9a_row44_col2, #T_51f9a_row45_col0, #T_51f9a_row45_col1, #T_51f9a_row45_col2, #T_51f9a_row46_col0, #T_51f9a_row46_col1, #T_51f9a_row46_col2, #T_51f9a_row47_col0, #T_51f9a_row47_col1, #T_51f9a_row47_col2, #T_51f9a_row48_col0, #T_51f9a_row48_col1, #T_51f9a_row48_col2, #T_51f9a_row49_col0, #T_51f9a_row49_col1, #T_51f9a_row49_col2, #T_51f9a_row50_col0, #T_51f9a_row50_col1, #T_51f9a_row50_col2, #T_51f9a_row51_col0, #T_51f9a_row51_col1, #T_51f9a_row51_col2, #T_51f9a_row52_col0, #T_51f9a_row52_col1, #T_51f9a_row52_col2, #T_51f9a_row53_col0, #T_51f9a_row53_col1, #T_51f9a_row53_col2, #T_51f9a_row54_col0, #T_51f9a_row54_col1, #T_51f9a_row54_col2, #T_51f9a_row55_col0, #T_51f9a_row55_col1, #T_51f9a_row55_col2, #T_51f9a_row56_col0, #T_51f9a_row56_col1, #T_51f9a_row56_col2, #T_51f9a_row57_col0, #T_51f9a_row57_col1, #T_51f9a_row57_col2, #T_51f9a_row58_col0, #T_51f9a_row58_col1, #T_51f9a_row58_col2, #T_51f9a_row59_col0, #T_51f9a_row59_col1, #T_51f9a_row59_col2, #T_51f9a_row60_col0, #T_51f9a_row60_col1, #T_51f9a_row60_col2, #T_51f9a_row61_col0, #T_51f9a_row61_col1, #T_51f9a_row61_col2, #T_51f9a_row62_col0, #T_51f9a_row62_col1, #T_51f9a_row62_col2, #T_51f9a_row63_col0, #T_51f9a_row63_col1, #T_51f9a_row63_col2 ...
#   text-align: right;
# }
# </style>
# <table id="T_51f9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51f9a_level0_col0" class="col_heading level0 col0" >brand_name</th>
#       <th id="T_51f9a_level0_col1" class="col_heading level0 col1" >product_description</th>
#       <th id="T_51f9a_level0_col2" class="col_heading level0 col2" >price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >serial. number.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51f9a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_51f9a_row0_col0" class="data row0 col0" >Nike</td>
#       <td id="T_51f9a_row0_col1" class="data row0 col1" >Men Air Max Sneakers</td>
#       <td id="T_51f9a_row0_col2" class="data row0 col2" >Rs. 8295</td>
#     </tr>
#     <tr>
#       <th id="T_51f9a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_51f9a_row1_col0" class="data row1 col0" >Puma</td>
#       <td id="T_51f9a_row1_col1" class="data row1 col1" ></td>
#       <td id="T_51f9a_row1_col2" class="data row1 col2" >Rs. 8449Rs. 12999(35% OFF)</td>
#     </tr>
#     <tr>
#       <th id="T_51f9a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_51f9a_row2_col0" class="data row2 col0" >Tommy Hilfiger</td>
#       <td id="T_51f9a_row2_col1" class="data row2 col1" >Men Solid Sneakers</td>
#       <td id="T_51f9a_row2_col2" class="data row2 col2" >Rs. 6639Rs. 8299(20% OFF)</td>
#     </tr>
#     <tr>
#       <th id="T_51f9a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_51f9a_row3_col0" class="data ro

# %% [markdown]
# # (Q8)

# %% [markdown]
# Go to webpage https://www.amazon.in/
#
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7”
#
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver= webdriver.Chrome(r"chromedriver.exe")

driver.get("https://www.amazon.in/")

# %%
des= driver.find_element(By.XPATH, "/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
des.send_keys("Laptop")

# %%
search= driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
cpu_filter_i7 = driver.find_element(By.XPATH,'//li[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/span')
cpu_filter_i7.click()

# %%
title=[]
ratings=[]
price=[]

# %%
title_tags = driver.find_elements(By.XPATH,"//span[@class='a-size-medium a-color-base a-text-normal']")
for i in title_tags[0:10]:
    x= i.text
    title.append(x)
title
# Out:
# ['Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN',
#  'Samsung Galaxy Book2 360 Intel 12th Gen i7 EvoTM 33.78cm (13.3") AMOLED 2 in 1 Touch Screen Laptop (16 GB/512 GB SSD/Windows 11/MS Office/Backlit KB/Fingerprint Sensor/Graphite/1.16Kg), NP730QED-KA1IN',
#  'ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FHD OLED, Intel EVO Core i7-1165G7 11th Gen, Thin and Light Laptop (16GB/1TB SSD/Iris Xe Graphics/Windows 11/Office 2021/Mist/1.14 kg), UX325EA-KG701WS',
#  'ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, Intel Core i7-1065G7 10th Gen, Thin and Light Laptop (16GB/512GB SSD/Iris Plus Graphics/Windows 11/Office 2021/Silver/1.8 kg), X515JA-EJ701WS',
#  'Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN',
#  'Lenovo ThinkBook 15 Intel 11th Gen Core i7 15.6"(39.62 cm)FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11 Home/MS Office H&S 2021/Iris® Xe Graphics/Backlit/Mineral Grey/1.7 Kg) 20VE00W4IH',
#  'Hp Pavilion 15 12Th Gen Intel Core I7 16Gb Sdram/1Tb Ssd 15.6 Inches (39.6Cm) Fhd,IPS/Intel Iris Xe Graphics/B&O/Windows 11 Home/Alexa/Backlit Kb/Fpr/Mso 2021/1.75Kg, 15-Eg2039Tu, Natural Silver',
#  'Lenovo Yoga 7i 11th Gen Intel Core i7-1165G7 14 inches FHD IPS 2-in-1 Touchscreen Business Laptop (16GB/512GB SSD/Windows 10/MS Office/Digital Pen/Fingerprint Reader/Slate Grey/1.43Kg), 82BH004HIN',
#  'Acer Nitro 5 Core i7 11th Gen 15.6" (39.62cms) Full HD IPS Gaming Laptop (16 GB/512 GB SSD/Win 11/4 GB Graphics/NVIDIA GeForce RTX 3050 Ti/144 Hz, Black, 2.2 kg) AN515-57',
#  'Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD IPS 400Nits 2-in1 Touch Convertible Laptop (16GB/1TB SSD/Windows 11/MS Office 2021/Iris Xe Graphics/2 Yr Warranty/Backlit Kb/Black/0.997 kg, 4ZR1F38027)']

# %%
rating_tags=driver.find_elements(By.XPATH,"//a[@class='a-popover-trigger a-declarative']")

for i in rating_tags[0:10]:
    if i.text is None:
        ratings.append("--")
    else:
        ratings.append(i.get_attribute("text"))

# %%
ratings
# Out:
# ['4.4 out of 5 stars',
#  '3.9 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.8 out of 5 stars',
#  '4.4 out of 5 stars',
#  '4.3 out of 5 stars',
#  '3.6 out of 5 stars',
#  '4.4 out of 5 stars',
#  '4.2 out of 5 stars',
#  '5.0 out of 5 stars']

# %%
price_tags=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in price_tags[0:10]:
    x= i.text
    price.append(x)
price
# Out:
# ['80,000',
#  '98,290',
#  '74,990',
#  '63,499',
#  '80,000',
#  '77,990',
#  '91,090',
#  '1,12,999',
#  '89,990',
#  '1,00,000']

# %%
list_data= list(zip(title, ratings, price))

df= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=11, name='serial. number.'),
        columns =['name_of_the_laptop', 'ratings', 'price'])

df = df.style.set_properties(**{'text-align': 'right'})

print ("first 10 laptop's on Amazon - \n\n")
df
# Out:
# first 10 laptop's on Amazon -
# <style type="text/css">
# #T_528f7_row0_col0, #T_528f7_row0_col1, #T_528f7_row0_col2, #T_528f7_row1_col0, #T_528f7_row1_col1, #T_528f7_row1_col2, #T_528f7_row2_col0, #T_528f7_row2_col1, #T_528f7_row2_col2, #T_528f7_row3_col0, #T_528f7_row3_col1, #T_528f7_row3_col2, #T_528f7_row4_col0, #T_528f7_row4_col1, #T_528f7_row4_col2, #T_528f7_row5_col0, #T_528f7_row5_col1, #T_528f7_row5_col2, #T_528f7_row6_col0, #T_528f7_row6_col1, #T_528f7_row6_col2, #T_528f7_row7_col0, #T_528f7_row7_col1, #T_528f7_row7_col2, #T_528f7_row8_col0, #T_528f7_row8_col1, #T_528f7_row8_col2, #T_528f7_row9_col0, #T_528f7_row9_col1, #T_528f7_row9_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_528f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_528f7_level0_col0" class="col_heading level0 col0" >name_of_the_laptop</th>
#       <th id="T_528f7_level0_col1" class="col_heading level0 col1" >ratings</th>
#       <th id="T_528f7_level0_col2" class="col_heading level0 col2" >price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >serial. number.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_528f7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_528f7_row0_col0" class="data row0 col0" >Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN</td>
#       <td id="T_528f7_row0_col1" class="data row0 col1" >4.4 out of 5 stars</td>
#       <td id="T_528f7_row0_col2" class="data row0 col2" >80,000</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_528f7_row1_col0" class="data row1 col0" >Samsung Galaxy Book2 360 Intel 12th Gen i7 EvoTM 33.78cm (13.3") AMOLED 2 in 1 Touch Screen Laptop (16 GB/512 GB SSD/Windows 11/MS Office/Backlit KB/Fingerprint Sensor/Graphite/1.16Kg), NP730QED-KA1IN</td>
#       <td id="T_528f7_row1_col1" class="data row1 col1" >3.9 out of 5 stars</td>
#       <td id="T_528f7_row1_col2" class="data row1 col2" >98,290</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_528f7_row2_col0" class="data row2 col0" >ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FHD OLED, Intel EVO Core i7-1165G7 11th Gen, Thin and Light Laptop (16GB/1TB SSD/Iris Xe Graphics/Windows 11/Office 2021/Mist/1.14 kg), UX325EA-KG701WS</td>
#       <td id="T_528f7_row2_col1" class="data row2 col1" >5.0 out of 5 stars</td>
#       <td id="T_528f7_row2_col2" class="data row2 col2" >74,990</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_528f7_row3_col0" class="data row3 col0" >ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, Intel Core i7-1065G7 10th Gen, Thin and Light Laptop (16GB/512GB SSD/Iris Plus Graphics/Windows 11/Office 2021/Silver/1.8 kg), X515JA-EJ701WS</td>
#       <td id="T_528f7_row3_col1" class="data row3 col1" >3.8 out of 5 stars</td>
#       <td id="T_528f7_row3_col2" class="data row3 col2" >63,499</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_528f7_row4_col0" class="data row4 col0" >Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN</td>
#       <td id="T_528f7_row4_col1" class="data row4 col1" >4.4 out of 5 stars</td>
#       <td id="T_528f7_row4_col2" class="data row4 col2" >80,000</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_528f7_row5_col0" class="data row5 col0" >Lenovo ThinkBook 15 Intel 11th Gen Core i7 15.6"(39.62 cm)FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11 Home/MS Office H&S 2021/Iris® Xe Graphics/Backlit/Mineral Grey/1.7 Kg) 20VE00W4IH</td>
#       <td id="T_528f7_row5_col1" class="data row5 col1" >4.3 out of 5 stars</td>
#       <td id="T_528f7_row5_col2" class="data row5 col2" >77,990</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_528f7_row6_col0" class="data row6 col0" >Hp Pavilion 15 12Th Gen Intel Core I7 16Gb Sdram/1Tb Ssd 15.6 Inches (39.6Cm) Fhd,IPS/Intel Iris Xe Graphics/B&O/Windows 11 Home/Alexa/Backlit Kb/Fpr/Mso 2021/1.75Kg, 15-Eg2039Tu, Natural Silver</td>
#       <td id="T_528f7_row6_col1" class="data row6 col1" >3.6 out of 5 stars</td>
#       <td id="T_528f7_row6_col2" class="data row6 col2" >91,090</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_528f7_row7_col0" class="data row7 col0" >Lenovo Yoga 7i 11th Gen Intel Core i7-1165G7 14 inches FHD IPS 2-in-1 Touchscreen Business Laptop (16GB/512GB SSD/Windows 10/MS Office/Digital Pen/Fingerprint Reader/Slate Grey/1.43Kg), 82BH004HIN</td>
#       <td id="T_528f7_row7_col1" class="data row7 col1" >4.4 out of 5 stars</td>
#       <td id="T_528f7_row7_col2" class="data row7 col2" >1,12,999</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_528f7_row8_col0" class="data row8 col0" >Acer Nitro 5 Core i7 11th Gen 15.6" (39.62cms) Full HD IPS Gaming Laptop (16 GB/512 GB SSD/Win 11/4 GB Graphics/NVIDIA GeForce RTX 3050 Ti/144 Hz, Black, 2.2 kg) AN515-57</td>
#       <td id="T_528f7_row8_col1" class="data row8 col1" >4.2 out of 5 stars</td>
#       <td id="T_528f7_row8_col2" class="data row8 col2" >89,990</td>
#     </tr>
#     <tr>
#       <th id="T_528f7_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_528f7_row9_col0" class="data row9 col0" >Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD IPS 400Nits 2-in1 Touch Convertible Laptop (16GB/1TB SSD/Windows 11/MS Office 2021/Iris Xe Graphics/2 Yr Warranty/Backlit Kb/Black/0.997 kg, 4ZR1F38027)</td>
#       <td id="T_528f7_row9_col1" class="data row9 col1" >5.0 out of 5 stars</td>
#       <td id="T_528f7_row9_col2" class="data row9 col2" >1,00,000</td>
#     </tr>
#   </tbody>
# </table>
